# %%
import cv2,numpy as np

image=cv2.imread("lab2-task2-image.jpg")
"""cv2.imshow("image",image)
cv2.waitKey(0)"""
# Out:
# 'cv2.imshow("image",image)\ncv2.waitKey(0)'

# %%
image[(image[:,:,0]>=120)*(image[:,:,1]<120)]=[255,0,255]
image[(image[:,:,1]>=120)*(image[:,:,0]<120)]=[255,255,0]

image[(image[:,:,2]>=120)*(image[:,:,0]<120)]=[0,255,255]

cv2.imshow("image",image)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
#Lab Task 1


image=cv2.imread("lab2_task1_1.jpg",0)
image[image<128]=0
image[image>=128]=255
"""cv2.imshow("he",image)
cv2.waitKey(0)
cv2.destroyAllWindows()"""
# Out:
# 'cv2.imshow("he",image)\ncv2.waitKey(0)\ncv2.destroyAllWindows()'

# %%
labels={}

def get_value(key,verbose):
    global labels
    try:
        if(verbose):
            print "Helllllllllllllllllllllllllllllllllo",key
        
        if(labels[key]==key):

            return key
        else:
            return get_value(labels[key])
    except:
        pass
def assign(big,small,verbose):
    global labels
    new1=get_value(big,verbose)
    new2=get_value(small,verbose)
    if(new1>=new2):
        labels[new1]=new2
    else:
        labels[new2]=new1
# Out:
# 'labels[1]=1\nlabels[2]=2\nlabels[3]=3\nlabels[4]=2\nlabels[5]=5\nlabels[6]=6\nlabels[7]=7\nlabels[8]=8\n\nassign(6,5)\nassign(5,1)\nassign(7,1)\nassign(7,3)\nassign(8,6)\nassign(8,7)\n '

# %%
copy=np.zeros_like(image)
rows,cols= image.shape
count=0


value=1 
print image.shape
 
for i in range(rows):
    for j in range(cols): 
         
        if(image[i,j]==255):
            pass
             
            
            """if(i-1 <0 and j-1<0):
                print "omer"
                labels[value]=value
                copy[value]=value
                value+=1



            elif(i-1<0):
                print "omer"

                if(copy[i,j-1]!=0):
                    copy[i,j]=copy[i,j-1]

                else:
                    copy[i,j]=value
                    labels[value]=value
                    value+=1


            elif(j-1<0):
                print "omer" 
                if(copy[i-1,j]!=0):
                    copy[i,j]=copy[i-1,j]
                else:
                    copy[i,j]=value
                    value+=1
                    labels[value]=value"""

        else:
            verbose=False
            black+=1
            low,high=-2,-2
            row,col=copy[i-1,j],copy[i,j-1]
            if(row!=0 or col!=0):
                if(row!=0 and col!=0):
                    
                    if(row==col):
                        
                        copy[i,j]=row
                      
                    else:
                        if(row<col):
                            low=row
                            high=col
                        else:
                            low=col
                            high=row 
                        count+=1
                        if(count==24289):
                            verbose=True
                            print high,low
                        if(verbose):
                            print "Now It should work"
                            print labels[186],labels[1],"Buhaha"
                        assign(high,low,verbose)
                        copy[i,j]=low
                         
                             
                elif(row==0 and col!=0):
                     copy[i,j]=col
                    
                else:
                    copy[i,j]=row
                       
                     
            else:
                
                copy[i,j]=value
                labels[value]=value
                print labels[value]
                value+=1
                
labels[6666]=55
print labels[6666],"Why not bro?"
for i in range(copy.shape[0]):
    for j in range(copy.shape[1]):
        copy[i,j]=get_value(copy[i,j])
# Out:
# (400, 600)
# None
# None
# 1
# None
# 2
# 3
# None
# 5
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# 123
# 125
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# None
# ...

# %%
print len (set(labels.keys()))
for i in range (image.shape[0]):
    for j in range(image.shape[1]):
         
        if(copy[i,j]==0):
            copy[i,j]=255
        else:
            try:
                value=labels[copy[i,j]]
                copy[i,j]=value
                if(value!=labels[value]):
                    copy[i,j]=labels[value]
                    
                
            except:
                continue
     
print "omer"

# %%
cv2.imshow("cc",image)
cv2.imshow("c",copy)
cv2.waitKey()

# %%
print set(labels.values())
